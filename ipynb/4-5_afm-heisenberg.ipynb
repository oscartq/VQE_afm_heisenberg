# %%
import os 
import sys
import datetime
import csv 

import cirq
import qsimcirq
import openfermion
import numpy as np
import multiprocessing as mp
Pi=3.1415

# %%
from functools import partial

# %% [markdown]
# ## anzats

# %%
class AnzatsAFMHeisenberg():
    def __init__(self, length, gamma, beta):

        # initialize circuit
        circuit = cirq.Circuit()
        qubits = cirq.LineQubit.range(length)


        for i in range(int(length/2)):
            circuit.append(cirq.H(qubits[int(2*i)]))
            circuit.append(cirq.Y(qubits[int(2*i)]))
            circuit.append(cirq.X(qubits[int(2*i+1)]))
            circuit.append(cirq.CNOT(qubits[int(2*i)], qubits[int(2*i+1)]))

        # add gamma circuit
        for index in range(gamma.size):
            # add gates on 2n and 2n+1
            for i in range(1, length-1, 2):
                circuit.append(
                    cirq.XX(qubits[i], qubits[(i+1)]) ** (-gamma[index]*2/Pi)
                    )
                circuit.append(
                    cirq.YY(qubits[i], qubits[(i+1)]) ** (-gamma[index]*2/Pi)
                    )
                circuit.append(
                    cirq.ZZ(qubits[i], qubits[(i+1)]) ** (-gamma[index]*2/Pi)
                    )
            # add gates on 2n-1 and 2n

            # add beta circuit
            for i in range(0, length-1, 2):
                circuit.append(
                    cirq.XX(qubits[i], qubits[(i+1)]) ** (-beta[index]*2/Pi)
                    )
                circuit.append(
                    cirq.YY(qubits[i], qubits[(i+1)]) ** (-beta[index]*2/Pi)
                    )
                circuit.append(
                    cirq.ZZ(qubits[i], qubits[(i+1)]) ** (-beta[index]*2/Pi)
                    )

        self.circuit = circuit
        self.qubits = qubits
        self.gamma = gamma
        self.beta = beta

# %% [markdown]
# ## expectation

# %%
class AFMHeisenbergArgs():
    def __init__(self, length, qsim_option):
        self.length = length
        self.qsim_option = qsim_option


def get_expectation_afm_heisenberg(function_args, gamma, beta):
    anzats = AnzatsAFMHeisenberg(function_args.length, gamma, beta)
    circuit = anzats.circuit
    qubits = anzats.qubits
    simulator = qsimcirq.QSimSimulator(function_args.qsim_option)
    vector = simulator.simulate(circuit).state_vector()

    value = 0 + 0j
    for i in range(function_args.length-1):
        circuitX = anzats.circuit.copy()
        circuitY = anzats.circuit.copy()
        circuitZ = anzats.circuit.copy()

        circuitX.append(cirq.X(qubits[i]))
        circuitX.append(cirq.X(qubits[(i+1)]))
        vector2 = simulator.simulate(circuitX).state_vector()
        value += np.dot(vector2.conj(), vector)

        circuitY.append(cirq.Y(qubits[i]))
        circuitY.append(cirq.Y(qubits[(i+1)]))
        vector2 = simulator.simulate(circuitY).state_vector()
        value += np.dot(vector2.conj(), vector)

        circuitZ.append(cirq.Z(qubits[i]))
        circuitZ.append(cirq.Z(qubits[(i+1)]))
        vector2 = simulator.simulate(circuitZ).state_vector()
        value += np.dot(vector2.conj(), vector)
    return value

# %% [markdown]
# ## optimization

# %%
def get_gradient(function, gamma: np.array, beta: np.array, delta_gamma, delta_beta, iter):
    grad_gamma = np.zeros_like(gamma)
    grad_beta  = np.zeros_like(beta)
    gamma_edge = gamma
    beta_edge  = beta
    # initial gamma, beta?
    
    if not (gamma.size == beta.size):
        return 1

    for index in range(gamma.size):
        center = gamma[index]
        gamma_edge[index] = gamma[index] - delta_gamma
        e1 = function(gamma=gamma_edge, beta=beta)
        gamma_edge[index] = gamma[index] + delta_gamma
        e2 = function(gamma=gamma_edge, beta=beta)
        grad_gamma[index] = (e2.real-e1.real)/(2*delta_gamma)
        gamma[index] = center

        center = beta[index]
        beta_edge[index] = beta[index] - delta_beta
        e1 = function(gamma=gamma, beta=beta_edge)
        beta_edge[index] = beta[index] + delta_beta
        e2 = function(gamma=gamma, beta=beta_edge)
        grad_beta[index] = (e2.real-e1.real)/(2*delta_beta)
        beta[index] = center
    
    return grad_gamma, grad_beta


def optimize_by_gradient_descent(function, initial_gamma: np.array, initial_beta: np.array, alpha, delta_gamma, delta_beta, iteration, figure=True,filepath=""):
    gamma, beta = initial_gamma, initial_beta

    textlines = []
    headline = ["iter", "energy"]
    for p in range(int(len(initial_gamma))):
        headline.append("gamma[{}]".format(p))
        headline.append("bata[{}]".format(p))
    print(headline)
    textlines.append(headline)

    for iter in range(int(iteration)):
        # it is complex for me to set get_gradient for two optical parameter_vector
        grad_gamma, grad_beta = get_gradient(function, gamma, beta, delta_gamma, delta_beta, iter)
        gamma -= alpha * grad_gamma
        beta  -= alpha * grad_beta
        energy = function(gamma=gamma, beta=beta)

        record = [iter, energy]
        for index in range(gamma.size):
            record.append(gamma[index])
            record.append(beta[index])
        textlines.append(record)
        print(record)
    
    if len(filepath)>0:
        with open(filepath, mode='a') as f:
            writer = csv.writer(f)
            for i, textline in enumerate(textlines):
                writer.writerow(textline)
                # f.write("{}\n".format(textline))

    return gamma, beta

# %% [markdown]
# ## case: length 2, optimize gamma and beta

# %%
length = 2
gamma = np.array([2.0])
beta  = np.array([2.0])
qsim_option = {'t': int(length/2), 'f':1}
function_args = AFMHeisenbergArgs(length, qsim_option)

anzats = AnzatsAFMHeisenberg(length, gamma, beta)
circuit = anzats.circuit
print(circuit)

simulator = cirq.Simulator()
result = simulator.simulate(circuit, qubit_order=anzats.qubits)
vector = cirq.final_state_vector(circuit)
print(result)

norm = np.dot(vector.conjugate(), vector)
print("norm: {}".format(norm))

value = get_expectation_afm_heisenberg(function_args,gamma, beta)
print("expectation on afm: {}".format(value))

initial_gamma = np.array([0.1, 0.2])
initial_beta  = np.array([0.1, 0.2])
iteration = 100
alpha = 0.1
delta_gamma = 0.0001
delta_beta  = 0.0001
gamma, beta = optimize_by_gradient_descent(partial(get_expectation_afm_heisenberg, function_args=function_args), initial_gamma, initial_beta, alpha, delta_gamma, delta_beta, iteration)

print(gamma, beta)
# Out:
# 0: ───H───Y───@───XX──────────YY──────────ZZ──────────
#               │   │           │           │
# 1: ───X───────X───XX^(8/11)───YY^(8/11)───ZZ^(8/11)───
# measurements: (no measurements)
#
# qubits: (cirq.LineQubit(0), cirq.LineQubit(1))
# output vector: (0.379-0.597j)|01⟩ + (-0.379+0.597j)|10⟩
#
# phase:
# output vector: |⟩
# norm: (0.9999999403953552+0j)
# expectation on afm: (-5.999998569488525+0j)
# ['iter', 'energy', 'gamma[0]', 'bata[0]', 'gamma[1]', 'bata[1]']
# [0, (-6.000002145767212+0j), 0.1, 0.09892711639404297, 0.2, 0.1994635581970215]
# [1, (-5.999999642372131+0j), 0.1, 0.09928474426269532, 0.2, 0.19982118606567384]
# [2, (-6.000000715255737+0j), 0.1, 0.09964237213134766, 0.2, 0.2007152557373047]
# [3, (-5.999998927116394+0j), 0.1, 0.10053644180297852, 0.2, 0.20035762786865235]
# [4, (-5.999999284744263+0j), 0.1, 0.10143051147460938, 0.2, 0.20107288360595704]
# [5, (-5.999999284744263+0j), 0.1, 0.1, 0.2, 0.2007152557373047]
# [6, (-6.000002861022949+0j), 0.1, 0.09892711639404297, 0.2, 0.2]
# [7, (-5.999998211860657+0j), 0.1, 0.10035762786865235, 0.2, 0.2007152557373047]
# [8, (-6.000000715255737+0j), 0.1, 0.09964237213134766, 0.2, 0.1994635581970215]
# [9, (-5.999998927116394+0j), 0.1, 0.1, 0.2, 0.19982118606567384]
# [10, (-5.999998927116394+0j), 0.1, 0.09839067459106446, 0.2, 0.19928474426269532]
# [11, (-5.999998927116394+0j), 0.1, 0.0987483024597168, 0.2, 0.1987483024597168]
# [12, (-6+0j), 0.1, 0.0987483024597168, 0.2, 0.19856948852539064]
# [13, (-6.000000715255737+0j), 0.1, 0.09803304672241211, 0.2, 0.19785423278808595]
# [14, (-5.999998927116394+0j), 0.1, 0.09982118606567383, 0.2, 0.19785423278808595]
# [15, (-5.999999284744263+0j), 0.1, 0.10035762786865235, 0.2, 0.1982118606567383]
# [16, (-5.999998927116394+0j), 0.1, 0.1, 0.2, 0.19785423278808595]
# [17, (-6+0j), 0.1, 0.09910593032836915, 0.2, 0.1969601631164551]
# [18, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [19, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [20, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [21, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [22, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [23, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [24, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [25, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [26, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [27, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [28, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [29, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [30, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [31, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [32, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [33, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [34, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [35, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [36, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [37, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [38, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [39, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [40, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [41, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [42, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [43, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [44, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [45, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [46, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [47, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [48, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [49, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [50, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [51, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [52, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [53, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [54, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [55, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [56, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [57, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [58, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [59, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [60, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [61, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [62, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [63, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [64, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [65, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [66, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [67, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [68, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [69, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [70, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [71, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [72, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [73, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [74, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [75, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [76, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [77, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [78, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [79, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [80, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [81, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [82, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [83, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [84, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [85, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [86, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [87, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [88, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [89, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [90, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [91, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [92, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [93, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [94, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [95, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [96, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [97, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [98, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [99, (-5.999999642372131+0j), 0.1, 0.0987483024597168, 0.2, 0.1962449073791504]
# [0.1 0.2] [0.0987483  0.19624491]

# %% [markdown]
# ## case: length 4, static gamma and beta

# %%
length = 4
g = 0.8
gamma = np.array([0.5, 0.4, 0.3, 0.2])
beta  = np.array([0.7, 0.5, 0.3, 0.1])
qsim_option = {'t': int(length/2), 'f':1}
function_args = AFMHeisenbergArgs(length, qsim_option)

anzats = AnzatsAFMHeisenberg(length, gamma, beta)
circuit = anzats.circuit
print(circuit)

simulator = cirq.Simulator()
result = simulator.simulate(circuit, qubit_order=anzats.qubits)
vector = cirq.final_state_vector(circuit)
print(result)

norm = np.dot(vector.conjugate(), vector)
print("norm: {}".format(norm))

value = get_expectation_afm_heisenberg(function_args,gamma, beta)
print("expectation on afm: {}".format(value))
# Out:
# 0: ───H───Y───@───────────────────────────────────────XX──────────YY──────────ZZ──────────────────────────────────────────────XX──────────YY──────────ZZ──────────────────────────────────────────────XX──────────YY──────────ZZ──────────────────────────────────────────────XX──────────YY──────────ZZ──────────
#               │                                       │           │           │                                               │           │           │                                               │           │           │                                               │           │           │
# 1: ───X───────X───XX──────────YY──────────ZZ──────────XX^-0.446───YY^-0.446───ZZ^-0.446───XX──────────YY──────────ZZ──────────XX^-0.318───YY^-0.318───ZZ^-0.318───XX──────────YY──────────ZZ──────────XX^-0.191───YY^-0.191───ZZ^-0.191───XX──────────YY──────────ZZ──────────XX^-0.064───YY^-0.064───ZZ^-0.064───
#                   │           │           │                                               │           │           │                                               │           │           │                                               │           │           │
# 2: ───H───Y───@───XX^-0.318───YY^-0.318───ZZ^-0.318───XX──────────YY──────────ZZ──────────XX^-0.255───YY^-0.255───ZZ^-0.255───XX──────────YY──────────ZZ──────────XX^-0.191───YY^-0.191───ZZ^-0.191───XX──────────YY──────────ZZ──────────XX^-0.127───YY^-0.127───ZZ^-0.127───XX──────────YY──────────ZZ──────────
#               │                                       │           │           │                                               │           │           │                                               │           │           │                                               │           │           │
# 3: ───X───────X───────────────────────────────────────XX^-0.446───YY^-0.446───ZZ^-0.446───────────────────────────────────────XX^-0.318───YY^-0.318───ZZ^-0.318───────────────────────────────────────XX^-0.191───YY^-0.191───ZZ^-0.191───────────────────────────────────────XX^-0.064───YY^-0.064───ZZ^-0.064───
# measurements: (no measurements)
#
# qubits: (cirq.LineQubit(0), cirq.LineQubit(1), cirq.LineQubit(2), cirq.LineQubit(3))
# output vector: (-0.063-0.222j)|0011⟩ + (0.297-0.263j)|0101⟩ + (-0.234+0.485j)|0110⟩ + (-0.234+0.485j)|1001⟩ + (0.297-0.263j)|1010⟩ + (-0.063-0.222j)|1100⟩
#
# phase:
# output vector: |⟩
# norm: (1+0j)
# expectation on afm: (-3.771673619747162-5.960464477539063e-08j)

# %% [markdown]
# ## case: length 8, static gamma and beta (paper value)

# %%
length = 8
gamma = np.array([0.2496, 0.4808, 0.5260, 0.4503])
beta  = np.array([0.6845, 0.6559, 0.6048, 0.3180])
qsim_option = {'t': int(length/2), 'f':1}
function_args = AFMHeisenbergArgs(length, qsim_option)

anzats = AnzatsAFMHeisenberg(length, gamma, beta)
circuit = anzats.circuit
# print(circuit)

simulator = cirq.Simulator()
result = simulator.simulate(circuit, qubit_order=anzats.qubits)
vector = cirq.final_state_vector(circuit)
print(result)

norm = np.dot(vector.conjugate(), vector)
print("norm: {}".format(norm))

value = get_expectation_afm_heisenberg(function_args,gamma, beta)
print("expectation on afm: {}".format(value))
# Out:
# measurements: (no measurements)
#
# qubits: (cirq.LineQubit(0), cirq.LineQubit(1), cirq.LineQubit(2), cirq.LineQubit(3), cirq.LineQubit(4), cirq.LineQubit(5), cirq.LineQubit(6), cirq.LineQubit(7))
# output vector: [-1.01321511e-08+8.27530577e-09j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j -5.94119864e-09-1.03792019e-09j
#   0.00000000e+00+0.00000000e+00j -2.07100612e-08+1.80451032e-09j
#   8.16860002e-09-6.26723606e-09j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  9.03858322e-10+9.60362634e-09j
#  -2.95023672e-09+7.41995532e-09j  0.00000000e+00+0.00000000e+00j
#   5.58793545e-09+1.49011612e-08j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j
# [42, (-7.999965190887451-5.21540641784668e-08j), 1.7381052494049072, 1.7016993284225463, 1.7305372476577758, 1.7351577997207641]
# [43, (-7.999957084655762+7.450580596923828e-09j), 1.7379982590675354, 1.7017321109771728, 1.7306546688079834, 1.7352126359939575]
# [44, (-7.999961972236633+2.2351741790771484e-08j), 1.737890374660492, 1.7017380714416503, 1.730776858329773, 1.735206377506256]
# [45, (-7.999963998794556-2.2351741790771484e-08j), 1.737786066532135, 1.701755952835083, 1.7308769941329956, 1.735262405872345]
# [46, (-7.99996143579483+7.450580596923828e-09j), 1.7376740097999572, 1.701775026321411, 1.7310003757476806, 1.7353112816810607]
# [47, (-7.999965310096741-7.450580596923828e-09j), 1.7375604629516601, 1.7017908215522766, 1.7311243534088134, 1.7353413820266723]
# [48, (-7.99996817111969-1.4901161193847656e-08j), 1.7374573469161987, 1.701818835735321, 1.7312548875808715, 1.7354015827178955]
# [49, (-7.99996280670166-7.450580596923828e-08j), 1.7373581051826477, 1.7018310546875, 1.731372308731079, 1.7354373455047607]
# [50, (-7.9999635219573975+7.450580596923828e-09j), 1.7372251868247985, 1.7018441677093505, 1.7314760208129882, 1.7354379415512085]
# [51, (-7.999966382980347-2.9802322387695312e-08j), 1.737114918231964, 1.701888871192932, 1.7315919518470764, 1.735504400730133]
# [52, (-7.999964594841003+0j), 1.7370129942893981, 1.7018846988677978, 1.7317254662513732, 1.7355443358421325]
# [53, (-7.999963998794556-4.470348358154297e-08j), 1.7368979573249816, 1.701910924911499, 1.7318410992622375, 1.7355848670005798]
# [54, (-7.999966382980347-4.470348358154297e-08j), 1.7367888808250427, 1.701915693283081, 1.7319597125053405, 1.7356265902519226]
# [55, (-7.999964714050293+0j), 1.7366857647895813, 1.701947283744812, 1.7320801138877868, 1.7356599688529968]
# [56, (-7.999963164329529-5.960464477539063e-08j), 1.7365737080574035, 1.7020009279251098, 1.7322088599205017, 1.7356969237327575]
# [57, (-7.99996018409729+4.470348358154297e-08j), 1.7364670157432556, 1.7020444393157959, 1.7323358178138732, 1.735724937915802]
# [58, (-7.999965786933899+1.4901161193847656e-08j), 1.7363481044769287, 1.7020688772201538, 1.732462477684021, 1.735736858844757]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[116], line 11
#       8 delta_gamma = 0.001
#       9 delta_beta  = 0.001
# ---> 11 gamma, beta = optimize_by_gradient_descent(partial(get_expectation_afm_heisenberg, function_args=function_args), initial_gamma, initial_beta, alpha, delta_gamma, delta_beta, iteration)
#      13 print(gamma, beta)
#
# Cell In[112], line 44, in optimize_by_gradient_descent(function, initial_gamma, initial_beta, alpha, delta_gamma, delta_beta, iteration, figure, filepath)
#      40 textlines.append(headline)
#      42 for iter in range(int(iteration)):
#      43     # it is complex for me to set get_gradient for two optical parameter_vector
# ---> 44     grad_gamma, grad_beta = get_gradient(function, gamma, beta, delta_gamma, delta_beta, iter)
#      45     gamma -= alpha * grad_gamma
#      46     beta  -= alpha * grad_beta
#
# Cell In[112], line 22, in get_gradient(function, gamma, beta, delta_gamma, delta_beta, iter)
#      20 center = beta[index]
#      21 beta_edge[index] = beta[index] - delta_beta
# ---> 22 e1 = function(gamma=gamma, beta=beta_edge)
#      23 beta_edge[index] = beta[index] + delta_beta
#      24 e2 = function(gamma=gamma, beta=beta_edge)
#
# Cell In[111], line 27, in get_expectation_afm_heisenberg(function_args, gamma, beta)
#      25 circuitY.append(cirq.Y(qubits[i]))
#      26 circuitY.append(cirq.Y(qubits[(i+1)%function_args.length]))
# ---> 27 vector2 = simulator.simulate(circuitY).state_vector()
#      28 value += np.dot(vector2.conj(), vector)
#      30 circuitZ.append(cirq.Z(qubits[i]))
#
# File ~/.local/lib/python3.11/site-packages/cirq/sim/simulator.py:495, in SimulatesFinalState.simulate(self, program, param_resolver, qubit_order, initial_state)
#     470 def simulate(
#     471     self,
#     472     program: 'cirq.AbstractCircuit',
#    (...)
#     475     initial_state: Any = None,
#     476 ) -> TSimulationTrialResult:
#     477     """Simulates the supplied Circuit.
#     478
#     479     This method returns a result which allows access to the entire
#    (...)
#     493         SimulationTrialResults for the simulation. Includes the final state.
#     494     """
# --> 495     return self.simulate_sweep(
#     496         program, study.ParamResolver(param_resolver), qubit_order, initial_state
#     497     )[0]
#
# File ~/.local/lib/python3.11/site-packages/cirq/sim/simulator.py:510, in SimulatesFinalState.simulate_sweep(self, program, params, qubit_order, initial_state)
#     499 def simulate_sweep(
#     500     self,
#     501     program: 'cirq.AbstractCircuit',
#    (...)
#     504     initial_state: Any = None,
#     505 ) -> List[TSimulationTrialResult]:
#     506     """Wraps computed states in a list.
#     507
#     508     Prefer overriding `simulate_sweep_iter`.
#     509     """
# --> 510     return list(self.simulate_sweep_iter(program, params, qubit_order, initial_state))
#
# File ~/.pyenv/versions/3.11.2/lib/python3.11/site-packages/qsimcirq/qsim_simulator.py:557, in QSimSimulator.simulate_sweep_iter(self, program, params, qubit_order, initial_state)
#     520 def simulate_sweep_iter(
#     521     self,
#     522     program: cirq.Circuit,
#    (...)
#     525     initial_state: Optional[Union[int, np.ndarray]] = None,
#     526 ) -> Iterator[cirq.StateVectorTrialResult]:
#     527     """Simulates the supplied Circuit.
#     528
#     529     This method returns a result which allows access to the entire
#    (...)
#     554         TypeError: if an invalid initial_state is provided.
#     555     """
# --> 557     for prs, state_vector, cirq_order in self._simulate_impl(
#     558         program, params, qubit_order, initial_state
#     559     ):
#     560         final_state = cirq.StateVectorSimulationState(
#     561             initial_state=state_vector, qubits=cirq_order
#     562         )
#     563         # create result for this parameter
#     564         # TODO: We need to support measurements.
#
# File ~/.pyenv/versions/3.11.2/lib/python3.11/site-packages/qsimcirq/qsim_simulator.py:486, in QSimSimulator._simulate_impl(self, program, params, qubit_order, initial_state)
#     483 for prs in param_resolvers:
#     484     solved_circuit = cirq.resolve_parameters(program, prs)
# --> 486     options["c"], _ = self._translate_circuit(
#     487         solved_circuit,
#     488         translator_fn_name,
#     489         cirq_order,
#     490     )
#     491     options["s"] = self.get_seed()
#     493     if isinstance(initial_state, int):
#
# File ~/.pyenv/versions/3.11.2/lib/python3.11/site-packages/qsimcirq/qsim_simulator.py:835, in QSimSimulator._translate_circuit(self, circuit, translator_fn_name, qubit_order)
#     832         return translated, moment_indices
#     834 translator_fn = getattr(circuit, translator_fn_name)
# --> 835 translated, moment_indices = translator_fn(qubit_order)
#     836 self._translated_circuits.append((circuit, translated, moment_indices))
#     838 return translated, moment_indices
#
# File ~/.pyenv/versions/3.11.2/lib/python3.11/site-packages/qsimcirq/qsim_circuit.py:431, in QSimCircuit.translate_cirq_to_qsim(self, qubit_order)
#     429         qsim_op = gate_ops[gi]
#     430         time = time_offset + gi
# --> 431         add_op_to_circuit(qsim_op, time, qubit_to_index_dict, qsim_circuit)
#     432         gate_count += 1
#     433 time_offset += moment_length
#
# File ~/.pyenv/versions/3.11.2/lib/python3.11/site-packages/qsimcirq/qsim_circuit.py:329, in add_op_to_circuit(qsim_op, time, qubit_to_index_dict, circuit)
#     327         raise ValueError("Parameters must be numeric.")
#     328 if isinstance(circuit, qsim.Circuit):
# --> 329     qsim.add_gate(gate_kind, time, qsim_qubits, params, circuit)
#     330 else:
#     331     qsim.add_gate_channel(gate_kind, time, qsim_qubits, params, circuit)
#
# KeyboardInterrupt:

# %% [markdown]
# ## case: length 8, optimize beta and gamma

# %%
length = 8
p = 4
initial_gamma = np.array([0.5 for i in range(p)])
initial_beta  = np.array([0.5 for i in range(p)])
qsim_option = {'t': int(length/2), 'f':1}
function_args = AFMHeisenbergArgs(length, qsim_option)

iteration = 10
alpha = 0.001
delta_gamma = 0.001
delta_beta  = 0.001

# print("exact energy: ")
# print(-1.28*length)

gamma, beta = optimize_by_gradient_descent(partial(get_expectation_afm_heisenberg, function_args=function_args), initial_gamma, initial_beta, alpha, delta_gamma, delta_beta, iteration)

print(gamma, beta)
# Out:
# ['iter', 'energy', 'gamma[0]', 'bata[0]', 'gamma[1]', 'bata[1]', 'gamma[2]', 'bata[2]', 'gamma[3]', 'bata[3]']
# [0, (-8.339006152004004-1.955777406692505e-08j), 0.4914024490863085, 0.5132264662533998, 0.5018216259777546, 0.5136496815830469, 0.5028650257736444, 0.5123851168900728, 0.49070058204233646, 0.5012611392885447]
# [1, (-9.63614897057414-5.587935447692871e-08j), 0.48278083093464375, 0.5252001415938139, 0.5040623303502798, 0.5276437029242516, 0.5050302352756262, 0.5251512918621302, 0.4811694510281086, 0.5018834266811609]
# [2, (-10.656131029129028+1.280568540096283e-08j), 0.47481832653284073, 0.5348623935133219, 0.5072556603699923, 0.5404608827084303, 0.5071414280682802, 0.5369598902761936, 0.4721646402031183, 0.5016213059425354]
# [3, (-11.350390937179327+6.332993507385254e-08j), 0.46808947809040546, 0.5417153285816312, 0.5115873860195279, 0.5509266322478652, 0.5097008515149355, 0.5467914417386055, 0.4642690820619464, 0.5004437072202563]
# [4, (-11.80169004574418+4.6566128730773926e-09j), 0.46275811828672886, 0.5460129296407104, 0.5167989488691092, 0.5588001608848572, 0.5127715189009905, 0.5544522227719426, 0.45765099208801985, 0.49857001658529043]
# [5, (-12.108168758451939-2.1653249859809875e-08j), 0.4586816895753145, 0.5484000220894814, 0.5224592741578817, 0.5644846195355058, 0.5161376781761646, 0.5603428203612566, 0.4521434102207422, 0.49629904981702566]
# [6, (-12.332054357975721+1.1641532182693481e-08j), 0.4555966053158045, 0.5495002921670675, 0.528194802813232, 0.5685551585629582, 0.5195576371625066, 0.5649975407868624, 0.44749751314520836, 0.4938931642100215]
# [7, (-12.505397073924541-6.565824151039124e-08j), 0.4532696604728699, 0.5497772637754679, 0.5337718995288014, 0.5715027647092938, 0.5228395266458392, 0.5688554206863046, 0.44347744807600975, 0.49152247328311205]
# [8, (-12.644241741858423+2.7939677238464355e-09j), 0.45151294209063053, 0.5495511875487864, 0.5390583416447043, 0.5736723141744733, 0.5258827642537653, 0.5722096581012011, 0.43993090093135834, 0.48928597662597895]
# [9, (-12.757526909001172+6.05359673500061e-08j), 0.45018362859264016, 0.5490128248929977, 0.5439939606003463, 0.5752853932790458, 0.5286371069960296, 0.5752410772256553, 0.4367321990430355, 0.4872586247511208]
# [0.45018363 0.54399396 0.52863711 0.4367322 ] [0.54901282 0.57528539 0.57524108 0.48725862]

# %% [markdown]
# ## case: length 8, optimize beta and gamma b

# %%
length = 8
p = 4
initial_gamma = np.array([0.5 for i in range(p)])
initial_beta  = np.array([0.5 for i in range(p)])
qsim_option = {'t': int(length/2), 'f':1}
function_args = AFMHeisenbergArgs(length, qsim_option

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[107], line 16
#      11 delta_beta  = 0.001
#      13 # print("exact energy: ")
#      14 # print(-1.28*length)
# ---> 16 gamma, beta = optimize_by_gradient_descent(partial(get_expectation_afm_heisenberg, function_args=function_args), initial_gamma, initial_beta, alpha, delta_gamma, delta_beta, iteration)
#      18 print(gamma, beta)
#
# Cell In[101], line 44, in optimize_by_gradient_descent(function, initial_gamma, initial_beta, alpha, delta_gamma, delta_beta, iteration, figure, filepath)
#      40 textlines.append(headline)
#      42 for iter in range(int(iteration)):
#      43     # it is complex for me to set get_gradient for two optical parameter_vector
# ---> 44     grad_gamma, grad_beta = get_gradient(function, gamma, beta, delta_gamma, delta_beta, iter)
#      45     gamma -= alpha * grad_gamma
#      46     beta  -= alpha * grad_beta
#
# Cell In[101], line 16, in get_gradient(function, gamma, beta, delta_gamma, delta_beta, iter)
#      14 e1 = function(gamma=gamma_edge, beta=beta)
#      15 gamma_edge[index] = gamma[index] + delta_gamma
# ---> 16 e2 = function(gamma=gamma_edge, beta=beta)
#      17 grad_gamma[index] = (e2.real-e1.real)/(2*delta_gamma)
#      18 gamma[index] = center
#
# Cell In[100], line 22, in get_expectation_afm_heisenberg(function_args, gamma, beta)
#      20 circuitX.append(cirq.X(qubits[i]))
#      21 circuitX.append(cirq.X(qubits[(i+1)%function_args.length]))
# ---> 22 vector2 = simulator.simulate(circuitX).state_vector()
#      23 value += np.dot(vector2.conj(), vector)
#      25 circuitY.append(cirq.Y(qubits[i]))
#
# File ~/.local/lib/python3.11/site-packages/cirq/sim/simulator.py:495, in SimulatesFinalState.simulate(self, program, param_resolver, qubit_order, initial_state)
#     470 def simulate(
#     471     self,
#     472     program: 'cirq.AbstractCircuit',
#    (...)
#     475     initial_state: Any = None,
#     476 ) -> TSimulationTrialResult:
#     477     """Simulates the supplied Circuit.
#     478
#     479     This method returns a result which allows access to the entire
#    (...)
#     493         SimulationTrialResults for the simulation. Includes the final state.
#     494     """
# --> 495     return self.simulate_sweep(
#     496         program, study.ParamResolver(param_resolver), qubit_order, initial_state
#     497     )[0]
#
# File ~/.local/lib/python3.11/site-packages/cirq/sim/simulator.py:510, in SimulatesFinalState.simulate_sweep(self, program, params, qubit_order, initial_state)
#     499 def simulate_sweep(
#     500     self,
#     501     program: 'cirq.AbstractCircuit',
#    (...)
#     504     initial_state: Any = None,
#     505 ) -> List[TSimulationTrialResult]:
#     506     """Wraps computed states in a list.
#     507
#     508     Prefer overriding `simulate_sweep_iter`.
#     509     """
# --> 510     return list(self.simulate_sweep_iter(program, params, qubit_order, initial_state))
#
# File ~/.pyenv/versions/3.11.2/lib/python3.11/site-packages/qsimcirq/qsim_simulator.py:557, in QSimSimulator.simulate_sweep_iter(self, program, params, qubit_order, initial_state)
#     520 def simulate_sweep_iter(
#     521     self,
#     522     program: cirq.Circuit,
#    (...)
#     525     initial_state: Optional[Union[int, np.ndarray]] = None,
#     526 ) -> Iterator[cirq.StateVectorTrialResult]:
#     527     """Simulates the supplied Circuit.
#     528
#     529     This method returns a result which allows access to the entire
#    (...)
#     554         TypeError: if an invalid initial_state is provided.
#     555     """
# --> 557     for prs, state_vector, cirq_order in self._simulate_impl(
#     558         program, params, qubit_order, initial_state
#     559     ):
#     560         final_state = cirq.StateVectorSimulationState(
#     561             initial_state=state_vector, qubits=cirq_order
#     562         )
#     563         # create result for this parameter
#     564         # TODO: We need to support measurements.
#
# File ~/.pyenv/versions/3.11.2/lib/python3.11/site-packages/qsimcirq/qsim_simulator.py:452, in QSimSimulator._simulate_impl(self, program, params, qubit_order, initial_state)
#     450 # Add noise to the circuit if a noise model was provided.
#     451 all_qubits = program.all_qubits()
# --> 452 program = qsimc.QSimCircuit(
#     453     self.noise.noisy_moments(program, sorted(all_qubits))
#     454     if self.noise is not cirq.NO_NOISE
#     455     else program,
#     456 )
#     458 options = {}
#     459 options.update(self.qsim_options)
#
# File ~/.pyenv/versions/3.11.2/lib/python3.11/site-packages/qsimcirq/qsim_circuit.py:354, in QSimCircuit.__init__(self, cirq_circuit, allow_decomposition)
#     352 else:
#     353     super().__init__(cirq_circuit)
# --> 354 self._check_for_confusion_matrix()
#
# File ~/.pyenv/versions/3.11.2/lib/python3.11/site-packages/qsimcirq/qsim_circuit.py:372, in QSimCircuit._check_for_confusion_matrix(self)
#     367 def _check_for_confusion_matrix(self):
#     368     """Checks cirq Circuit for Measurement Gates with confusion matrices.
#     369     Returns:
#     370         Throws a runtime exception if a MeasurementGate with a confusion matrix is included in the circuit
#     371     """
# --> 372     confusion_maps_on_measurement_gates = [
#     373         op.gate.confusion_map
#     374         for _, op, _ in self.findall_operations_with_gate_type(cirq.MeasurementGate)
#     375         if op.gate.confusion_map
#     376     ]
#     377     for confusion_map in confusion_maps_on_measurement_gates:
#     378         for map_values in confusion_map.values():
#
# File ~/.pyenv/versions/3.11.2/lib/python3.11/site-packages/qsimcirq/qsim_circuit.py:372, in <listcomp>(.0)
#     367 def _check_for_confusion_matrix(self):
#     368     """Checks cirq Circuit for Measurement Gates with confusion matrices.
#     369     Returns:
#     370         Throws a runtime exception if a MeasurementGate with a confusion matrix is included in the circuit
#     371     """
# --> 372     confusion_maps_on_measurement_gates = [
#     373         op.gate.confusion_map
#     374         for _, op, _ in self.findall_operations_with_gate_type(cirq.MeasurementGate)
#     375         if op.gate.confusion_map
#     376     ]
#     377     for confusion_map in confusion_maps_on_measurement_gates:
#     378         for map_values in confusion_map.values():
#
# File ~/.local/lib/python3.11/site-packages/cirq/circuits/circuit.py:792, in AbstractCircuit.findall_operations_with_gate_type(self, gate_type)
#     781 """Find the locations of all gate operations of a given type.
#     782
#     783 Args:
#    (...)
#     789     gate type.
#     790 """
#     791 result = self.findall_operations(lambda operation: isinstance(operation.gate, gate_type))
# --> 792 for index, op in result:
#     793     gate_op = cast(ops.GateOperation, op)
#     794     yield index, gate_op, cast(_TGate, gate_op.gate)
#
# File ~/.local/lib/python3.11/site-packages/cirq/circuits/circuit.py:775, in AbstractCircuit.findall_operations(self, predicate)
#     773 for index, moment in enumerate(self.moments):
#     774     for op in moment.operations:
# --> 775         if predicate(op):
#     776             yield index, op
#
# File ~/.local/lib/python3.11/site-packages/cirq/circuits/circuit.py:791, in AbstractCircuit.findall_operations_with_gate_type.<locals>.<lambda>(operation)
#     778 def findall_operations_with_gate_type(
#     779     self, gate_type: Type[_TGate]
#     780 ) -> Iterable[Tuple[int, 'cirq.GateOperation', _TGate]]:
#     781     """Find the locations of all gate operations of a given type.
#     782
#     783     Args:
#    (...)
#     789         gate type.
#     790     """
# --> 791     result = self.findall_operations(lambda operation: isinstance(operation.gate, gate_type))
#     792     for index, op in result:
#     793         gate_op = cast(ops.GateOperation, op)
#
# File <frozen abc>:117, in __instancecheck__(cls, instance)
#
# KeyboardInterrupt:

# %% [markdown]
# ## case: length 16, static beta and gamma

# %%
length = 16
p = 8
initial_gamma = np.array([0.5 for i in range(p)])
initial_beta  = np.array([0.5 for i in range(p)])
qsim_option = {'t': int(length/2), 'f':1}
function_args = AFMHeisenbergArgs(length, qsim_option)

iteration = 10
alpha = 0.01
delta_gamma = 0.001
delta_beta  = 0.001

# print("exact energy: ")
# print(-1.28*length)

value = get_expectation_afm_heisenberg(function_args,gamma, beta)
print("expectation on afm: {}".format(value))
# Out:
# expectation on afm: (-1.1298944614827633-1.3562384992837906e-08j)

# %% [markdown]
# ## playground

# %%
L = 10
circuit = cirq.Circuit()
qubits = cirq.LineQubit.range(L)

for i in range(1, L, 2):
    circuit.append(
        cirq.ZZPowGate(
            exponent=0.5, global_shift=0.0).on(
                qubits[i-1], qubits[i]
        )
    )


for i in range(2, L, 2):
    circuit.append(
        cirq.ZZPowGate(
            exponent=0.5, global_shift=0.0).on(
                qubits[i-1], qubits[i]
            )
    )


for i in range(L):
    circuit.append(
        cirq.XPowGate(
            exponent=0.5, global_shift=0.0).on(
            qubits[i])
    )


# for i in range(1, L, 2):
#     circuit.append(cirq.Z(qubits[i-1]))
#     circuit.append(cirq.Z(qubits[i]))


# for i in range(2, L, 2):
#     circuit.append(cirq.Y(qubits[i-1]))
#     circuit.append(cirq.Y(qubits[i]))


# for i in range(L):
#     circuit.append(cirq.X(qubits[i]))



print(circuit)
# Out:
# 0: ───ZZ───────X^0.5────────────
#       │
# 1: ───ZZ^0.5───ZZ───────X^0.5───
#                │
# 2: ───ZZ───────ZZ^0.5───X^0.5───
#       │
# 3: ───ZZ^0.5───ZZ───────X^0.5───
#                │
# 4: ───ZZ───────ZZ^0.5───X^0.5───
#       │
# 5: ───ZZ^0.5───ZZ───────X^0.5───
#                │
# 6: ───ZZ───────ZZ^0.5───X^0.5───
#       │
# 7: ───ZZ^0.5───ZZ───────X^0.5───
#                │
# 8: ───ZZ───────ZZ^0.5───X^0.5───
#       │
# 9: ───ZZ^0.5───X^0.5────────────

# %%
value = 0 + 0j

# circuit2 = circuit
# anzats2 = Anzats(length, gamma, beta)
# circuit2 = anzats2.circuit
# qubits = anzats2.qubits
# circuit2.append(
#         cirq.ZZPowGate(
#             exponent=1, global_shift=0.0).on(
#                 qubits[1], qubits[2]
#         ))
# print(circuit2)
# result2 = simulator.simulate(circuit2, qubit_order=anzats.qubits)
# vector2 = cirq.final_state_vector(circuit2)
# value -= np.dot(vector2.conjugate(), vector)

# print(value)

# # for i in range(length-1):
#     circuit2 = circuit.append(cirq.ZZ.on(
#         qubits[i], qubits[i+1]
#     ))
#     result2 = simulator.simulate(circuit2, qubit_order=anzats.qubits)
#     vector2 = cirq.final_state_vector(circuit2)
#     value -= np.dot(vector2.conjugate(), vector)
# else:
#     circuit2 = circuit.append(cirq.ZZ.on(
#         qubits[length-1], qubits[0]
#     ))
#     result2 = simulator.simulate(circuit2, qubit_order=anzats.qubits)
#     vector2 = cirq.final_state_vector(circuit2)
#     value -= np.dot(vector2.conjugate(), vector)

# %%
a = np.array([1,3])
a[1]
# Out:
# 3

# %%
print(vector)
# Out:
# [0.4591058 -4.49337065e-03j 0.12919496-1.25825405e-03j
#  0.12919495-1.25825033e-03j 0.07737847-7.35387206e-04j
#  0.12919495-1.25830155e-03j 0.04038734-3.95298004e-04j
#  0.07737847-7.35415146e-04j 0.06066927-5.82884997e-04j
# [89, 1.5769110164341176e-07, -0.0001785358530049387, 0.0003547055833155304]
# [90, 1.2936531990395887e-07, -0.00015568226770444483, 0.00032423502498397737]
# [91, 1.0635288393772245e-07, -0.00013511404093400034, 0.0002968115224855796]
# [92, 8.765111332351939e-08, -0.00011660263684060031, 0.00027213037023702164]
# [93, 7.244715139261849e-08, -9.994237315654027e-05, 0.00024991733321331946]
# [94, 6.008196726853199e-08, -8.494813584088624e-05, 0.0002299255998919875]
# [95, 5.0021190663970826e-08, -7.145332225679762e-05, 0.00021193303990278876]
# [96, 4.183148189663029e-08, -5.930799003111786e-05, 0.0001957397359125099]
# [97, 3.516138604920306e-08, -4.8377191028006064e-05, 0.0001811657623212589]
# [98, 2.9725819841493755e-08, -3.8539471925205455e-05, 0.000168049186089133]
# [99, 2.529350149908529e-08, -2.9685524732684907e-05, 0.0001562442674802197]
# [-2.96855247e-05] [0.00015624]

# %%
def function_norm(gamma, beta):
    return np.linalg.norm(gamma)**2 + np.linalg.norm(beta)**2

initial_gamma = np.array([3.0, 2.0])
initial_beta = np.array([4.0, 5.0])

final_gamma, final_beta = optimize_by_gradient_descent(
    function=function_norm,
    initial_gamma=initial_gamma,
    initial_beta=initial_beta,
    alpha=0.1,
    delta_gamma=0.001,
    delta_beta=0.001,
    iteration=100,
    Figure=True)
print(final_gamma, final_beta)
print(function_norm(gamma, beta))
# Out:
# ['iter', 'energy', 'gamma[0]', 'bata[0]', 'gamma[1]', 'bata[1]']
# [0, 43.741260009996445, 2.7000499999998624, 3.6000500000000955, 1.8000499999999846, 4.500049999999618]
# [1, 35.43155463610003, 2.4300949999999517, 3.2400950000003945, 1.6200949999998642, 4.0500949999997715]
# [2, 28.700579899441102, 2.1871354999997124, 2.9161355000003795, 1.4581354999997558, 3.6451354999999808]
# [3, 23.248388317329418, 1.9684719499996035, 2.6245719500004725, 1.3123719499998003, 3.2806719500002757]
# [4, 18.83202129493629, 1.7716747549995944, 2.3621647550002365, 1.1811847549998404, 2.9526547549999904]
# [5, 15.254681350009095, 1.5945572794996394, 2.1259982795000596, 1.0631162794997522, 2.657439279499947]
# [6, 12.35696160350955, 1.4351515515496267, 1.9134484515502557, 0.9568546515497083, 2.391745351550174]
# [7, 10.00974165684386, 1.2916863963946952, 1.7221536063953344, 0.8612191863947665, 2.1526208163951743]
# [8, 8.108433243244505, 1.162567756755248, 1.5499882457558698, 0.7751472677553366, 1.9374087347556923]
# [9, 6.568319197107911, 1.0463609810796832, 1.3950394211802184, 0.6976825409797698, 1.743717861280043]
# [10, 5.320778011730116, 0.9417748829717105, 1.2555854790622565, 0.6279642868817863, 1.569396075152092]
# [11, 4.310225724366429, 0.8476473946745529, 1.1300769311560064, 0.5652178581936322, 1.4125064676368382]
# [12, 3.4916388371156515, 0.7629326552071021, 1.0171192380404168, 0.5087460723743202, 1.2713058208731987]
# [13, 2.828547877404456, 0.6866893896863875, 0.9154573142363862, 0.45792146513687726, 1.1442252387858742]
# [14, 2.2914121771043803, 0.6180704507177532, 0.8239615828127675, 0.4121793186232052, 1.0298527149072934]
# [96, 1.5816910274304575e-06, 0.0006092879505669439, 0.0006457233399875773, 0.0005728525611464003, 0.0006821587294081108]
# [97, 1.5170717645184836e-06, 0.0005983591555102494, 0.0006311510059888196, 0.0005655673050317603, 0.0006639428564672998]
# [98, 1.460139958329803e-06, 0.0005885232399592246, 0.0006180359053899377, 0.0005590105745285842, 0.0006475485708205698]
# [99, 1.409894012409989e-06, 0.0005796709159633021, 0.0006062323148509439, 0.0005531095170757257, 0.0006327937137385128]
# [0.00057967 0.00055311] [0.00060623 0.00063279]
# 2.2537533517843826

# %%
length = 6
gamma = np.array([0.1, 0.1])
beta = np.array([0.1, 0.1])

anzats = Anzats(length, gamma, beta)
circuit = anzats.circuit
qubits = anzats.qubits
vector = cirq.final_state_vector(circuit)

ham_nd = np.zeros((length, length), dtype=np.complex128)

print(cirq.Z(qubits[-1]))
for i in range(length-1):
    circuit_ZiZj = cirq.Circuit()
    circuit_ZiZj.append(cirq.Z(qubits[i]))
    circuit_ZiZj.append(cirq.Z(qubits[i+1]))
    ham_nd += cirq.unitary(circuit_ZiZj)
else:
    circuit_ZiZj = cirq.Circuit()
    circuit_ZiZj.append(cirq.Z(qubits[length-1]))
    circuit_ZiZj.append(cirq.Z(qubits[0]))
    ham_nd += cirq.unitary(circuit_ZiZj)
    
print(ham_nd)


# def get_expectation_ZiZj(length, beta, gamma, qubit_ZZ_on_i, qubit_ZZ_on_j, print_circuit=False):
#     """
#     controls of append on circuit are accumulated.
#     we have to make circuits on each hamiltonian terms.
#     """
#     anzats = Anzats(length, gamma, beta)
#     circuit = anzats.circuit
#     qubits = anzats.qubits
#     vector = cirq.final_state_vector(circuit)

#     anzats = Anzats(length, gamma, beta)
#     circuit = anzats.circuit
#     qubits = anzats.qubits
#     circuit.append(cirq.Z(qubits[qubit_ZZ_on_i]))
#     circuit.append(cirq.Z(qubits[qubit_ZZ_on_j]))
#     if print_circuit:
#         print(circuit)
#     simulator = cirq.Simulator()
#     # result2 = simulator.simulate(circuit, qubit_order=qubits)
#     vector2 = cirq.final_state_vector(circuit)
#     return np.dot(vector2.conjugate(), vector)


# def get_expectation_ghz_l4(gamma: np.array, beta: np.array):
#     length = 4
#     value = 0 + 0j
#     for i in range(length-1):
#         value -= get_expectation_ZiZj(length, gamma, beta, i, i+1)
#     else:
#         value -= get_expectation_ZiZj(length, gamma, beta, length-1, 0)
#     return value


# def get_expectation_ghz_l8(gamma: np.array, beta: np.array):
#     length = 8
#     value = 0 + 0j
#     for i in range(length-1):
#         value -= get_expectation_ZiZj(length, gamma, beta, i, i+1)
#     else:
#         value -= get_expectation_ZiZj(length, gamma, beta, length-1, 0)
#     return value
# Out:
# Z(q(5))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 17
#      15     circuit_ZiZj.append(cirq.Z(qubits[i]))
#      16     circuit_ZiZj.append(cirq.Z(qubits[i+1]))
# ---> 17     ham_nd += cirq.unitary(circuit_ZiZj)
#      18 else:
#      19     circuit_ZiZj = cirq.Circuit()
#
# ValueError: operands could not be broadcast together with shapes (6,6) (4,4) (6,6)
